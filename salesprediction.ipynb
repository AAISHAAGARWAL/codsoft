# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.shape
# Out:
# (200, 4)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
print("maximum sale is 27 and minimum is 1.6")
# Out:
# maximum sale is 27 and minimum is 1.6

# %%
sns.pairplot(data, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', kind='scatter')
plt.show()

# %%
data['TV'].plot.hist(bins=10, xlabel='TV')
# Out:
# <Axes: xlabel='TV', ylabel='Frequency'>

# %%
data['Radio'].plot.hist(bins=10, color='green', xlabel='Radio')
# Out:
# <Axes: xlabel='Radio', ylabel='Frequency'>

# %%
data['Newspaper'].plot.hist(bins=10, color='red', xlabel='Newspaper')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Frequency'>

# %%
sns.heatmap(data.corr(), annot= True)
plt.show()

# %%
#sale is highly correlated with TV

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['TV']],data[['Sales']], test_size=0.3, random_state=0)

# %%
print(x_train)
# Out:
#         TV
# 131  265.2
# 96   197.6
# 181  218.5
# 19   147.3
# 153  171.3
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 131   17.7
# 96    16.7
# 181   17.2
# 19    14.6
# 153   16.0
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [140 rows x 1 columns]

# %%
print(x_test)
# Out:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# 63   102.7
# 8      8.6
# 75    16.9
# 118  125.7
# 143  104.6
# 71   109.8
# 124  229.5
# 184  253.8
# 97   184.9
# 149   44.7
# 24    62.3
# 30   292.9
# 160  172.5
# 40   202.5
# 56     7.3

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# 63    14.0
# 8      4.8
# 75     8.7
# 118   15.9
# 143   10.4
# 71    12.4
# 124   19.7
# 184   17.6
# 97    20.5
# 149   10.1
# 24     9.7
# 30    21.4
# 160   16.4
# 40    16.6
# 56     5.5

# %%
from sklearn.linear_model import LinearRegression

# Assuming x_train and y_train are already defined
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
res= model.predict(x_test)
print(res)
# Out:
# [[10.93127621]
#  [ 9.88042193]
#  [12.09159447]
#  [22.99968079]
#  [16.45920756]
#  [10.21976029]
#  [ 7.6199906 ]
#  [20.28497391]
#  [ 8.4464437 ]
#  [17.95886418]
#  [21.44529217]
#  [11.91645209]
#  [15.71485245]
#  [17.42249065]
#  [11.32534656]
#  [13.72260788]
#  [21.68063975]
#  [ 7.18213465]
#  [11.23230217]
#  [18.82362968]
#  [22.88474361]
#  [14.82272095]
#  [16.72739433]
#  [14.35202581]
#  [10.07198391]
#  [13.88133066]
#  [16.20744039]
#  [18.36388094]
#  [19.40378881]
#  [ 8.51759529]
#  [10.85465142]
#  [18.03001578]
#  [22.50709285]
#  [20.3725451 ]
#  [ 7.86628457]
#  [ 8.16731053]
#  [10.40584907]
#  [17.03936669]
#  [10.88749061]
#  [ 8.51212209]
#  [ 9.16343282]
#  [ 8.86788005]
#  [14.96502414]
#  [18.61564811]
#  [18.93309367]
#  [12.76479799]
#  [ 7.6145174 ]
#  [ 8.06879294]
#  [14.02363385]
#  [12.86878878]
#  [13.15339515]
#  [19.70481478]
#  [21.03480222]
#  [17.26376787]
#  [ 9.59034237]
#  [10.55362545]
#  [23.17482317]
#  [16.58509115]
# ...

# %%
plt.plot(res)

# %%
#RADIO
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['Radio']],data[['Sales']], test_size=0.3, random_state=0)

# %%
print(x_train)
# Out:
#      Radio
# 131    2.9
# 96     3.5
# 181    5.4
# 19    23.9
# 153   39.7
# ..     ...
# 67    14.5
# 192    4.1
# 117    0.8
# 47    41.5
# 172   20.1
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 131   17.7
# 96    16.7
# 181   17.2
# 19    14.6
# 153   16.0
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [140 rows x 1 columns]

# %%
print(x_test)
# Out:
#      Radio
# 18    20.5
# 170   11.6
# 107    0.3
# 98    42.3
# 177    7.8
# 182    5.7
# 5     48.9
# 146    7.3
# 12    35.1
# 152   23.3
# 61    42.7
# 125   11.8
# 180    2.6
# 154   21.1
# 80    26.7
# 7     19.6
# 33    20.0
# 130   39.6
# 37    49.4
# 74    24.6
# 183   43.0
# 145    1.9
# 45    22.5
# 159   18.4
# 60     2.0
# 123   34.6
# 179   10.0
# 185   45.1
# 122    2.4
# 44    25.7
# 16    36.6
# 55    49.4
# 150   13.9
# 111   38.0
# 22    15.9
# 189   12.1
# 129   12.0
# 4     10.8
# 83    44.5
# 106   11.0
# 134   38.6
# 66    24.6
# 26    29.3
# 113   20.6
# 168   23.6
# 63    29.6
# 8      2.1
# 75    43.7
# 118   36.9
# 143    5.7
# 71    14.3
# 124   32.3
# 184   21.3
# 97    21.0
# 149   25.8
# 24    12.6
# 30    28.3
# 160   18.1
# 40    22.3
# 56    28.1

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# 63    14.0
# 8      4.8
# 75     8.7
# 118   15.9
# 143   10.4
# 71    12.4
# 124   19.7
# 184   17.6
# 97    20.5
# 149   10.1
# 24     9.7
# 30    21.4
# 160   16.4
# 40    16.6
# 56     5.5

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
res= model.predict(x_test)
print(res)
plt.plot(res)
# Out:
# [[15.20461632]
#  [14.07873771]
#  [12.64925137]
#  [17.96238642]
#  [13.59802549]
#  [13.33236874]
#  [18.79730764]
#  [13.53477388]
#  [17.05156327]
#  [15.55882533]
#  [18.01298771]
#  [14.10403835]
#  [12.94020877]
#  [15.28051825]
#  [15.98893626]
#  [15.09076343]
#  [15.14136472]
#  [17.62082774]
#  [18.86055925]
#  [15.72327951]
#  [18.05093867]
#  [12.85165652]
#  [15.45762275]
#  [14.93895957]
#  [12.86430684]
#  [16.98831166]
#  [13.87633256]
#  [18.31659542]
#  [12.91490813]
#  [15.86243304]
#  [17.24131809]
#  [18.86055925]
#  [14.3696951 ]
#  [17.41842259]
#  [14.62270153]
#  [14.14198931]
#  [14.12933899]
#  [13.97753513]
#  [18.24069349]
#  [14.00283578]
#  [17.49432452]
#  [15.72327951]
#  [16.31784462]
#  [15.21726665]
#  [15.59677629]
#  [16.35579558]
#  [12.87695716]
#  [18.13949092]
#  [17.27926906]
#  [13.33236874]
#  [14.42029639]
#  [16.69735427]
#  [15.3058189 ]
#  [15.26786793]
#  [15.87508337]
#  [14.20524092]
#  [16.1913414 ]
#  [14.90100861]
# ...

# %%
#newspaper
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['Radio']],data[['Sales']], test_size=0.3, random_state=0)

# %%
print(x_train)
# Out:
#      Radio
# 131    2.9
# 96     3.5
# 181    5.4
# 19    23.9
# 153   39.7
# ..     ...
# 67    14.5
# 192    4.1
# 117    0.8
# 47    41.5
# 172   20.1
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 131   17.7
# 96    16.7
# 181   17.2
# 19    14.6
# 153   16.0
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [140 rows x 1 columns]

# %%
print(x_test)
# Out:
#      Radio
# 18    20.5
# 170   11.6
# 107    0.3
# 98    42.3
# 177    7.8
# 182    5.7
# 5     48.9
# 146    7.3
# 12    35.1
# 152   23.3
# 61    42.7
# 125   11.8
# 180    2.6
# 154   21.1
# 80    26.7
# 7     19.6
# 33    20.0
# 130   39.6
# 37    49.4
# 74    24.6
# 183   43.0
# 145    1.9
# 45    22.5
# 159   18.4
# 60     2.0
# 123   34.6
# 179   10.0
# 185   45.1
# 122    2.4
# 44    25.7
# 16    36.6
# 55    49.4
# 150   13.9
# 111   38.0
# 22    15.9
# 189   12.1
# 129   12.0
# 4     10.8
# 83    44.5
# 106   11.0
# 134   38.6
# 66    24.6
# 26    29.3
# 113   20.6
# 168   23.6
# 63    29.6
# 8      2.1
# 75    43.7
# 118   36.9
# 143    5.7
# 71    14.3
# 124   32.3
# 184   21.3
# 97    21.0
# 149   25.8
# 24    12.6
# 30    28.3
# 160   18.1
# 40    22.3
# 56    28.1

# %%
print(y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# 63    14.0
# 8      4.8
# 75     8.7
# 118   15.9
# 143   10.4
# 71    12.4
# 124   19.7
# 184   17.6
# 97    20.5
# 149   10.1
# 24     9.7
# 30    21.4
# 160   16.4
# 40    16.6
# 56     5.5

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
res= model.predict(x_test)
print(res)
plt.plot(res)
# Out:
# [[15.20461632]
#  [14.07873771]
#  [12.64925137]
#  [17.96238642]
#  [13.59802549]
#  [13.33236874]
#  [18.79730764]
#  [13.53477388]
#  [17.05156327]
#  [15.55882533]
#  [18.01298771]
#  [14.10403835]
#  [12.94020877]
#  [15.28051825]
#  [15.98893626]
#  [15.09076343]
#  [15.14136472]
#  [17.62082774]
#  [18.86055925]
#  [15.72327951]
#  [18.05093867]
#  [12.85165652]
#  [15.45762275]
#  [14.93895957]
#  [12.86430684]
#  [16.98831166]
#  [13.87633256]
#  [18.31659542]
#  [12.91490813]
#  [15.86243304]
#  [17.24131809]
#  [18.86055925]
#  [14.3696951 ]
#  [17.41842259]
#  [14.62270153]
#  [14.14198931]
#  [14.12933899]
#  [13.97753513]
#  [18.24069349]
#  [14.00283578]
#  [17.49432452]
#  [15.72327951]
#  [16.31784462]
#  [15.21726665]
#  [15.59677629]
#  [16.35579558]
#  [12.87695716]
#  [18.13949092]
#  [17.27926906]
#  [13.33236874]
#  [14.42029639]
#  [16.69735427]
#  [15.3058189 ]
#  [15.26786793]
#  [15.87508337]
#  [14.20524092]
#  [16.1913414 ]
#  [14.90100861]
# ...
